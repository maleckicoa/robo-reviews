# %%
import pandas as pd
from pathlib import Path
from transformers import pipeline
import kagglehub

# %% [markdown]
# ## LOAD DATA

# %%
pd.set_option('display.max_columns', None)

# Download all files
path = kagglehub.dataset_download("datafiniti/consumer-reviews-of-amazon-products")
csv_paths = list(Path(path).glob("*.csv"))


dfs = [pd.read_csv(p) for p in csv_paths]
df = pd.concat(dfs, ignore_index=True)

df = df.drop_duplicates(
    subset=['id', 'dateAdded', 'dateUpdated', 'reviews.text', 'reviews.title', 'reviews.username'],
    keep='first'
)

print(df.shape)
# Out:
# Using Colab cache for faster access to the 'consumer-reviews-of-amazon-products' dataset.
# /tmp/ipython-input-884188909.py:8: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(p) for p in csv_paths]
# (67896, 27)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# dateAdded               34660
# dateUpdated             34660
# name                     6760
# asins                       2
# brand                       0
# categories                  0
# primaryCategories       34660
# imageURLs               34660
# keys                        0
# manufacturer                0
# manufacturerNumber      34660
# reviews.date               39
# reviews.dateAdded       42813
# reviews.dateSeen            0
# reviews.doRecommend     12839
# reviews.id              67825
# reviews.numHelpful      12745
# reviews.rating             33
# reviews.sourceURLs          0
# reviews.text                1
# reviews.title              19
# reviews.username           13
# sourceURLs              34660
# reviews.didPurchase     67886
# reviews.userCity        67896
# reviews.userProvince    67896
# dtype: int64

# %%
df = df.dropna(subset=["reviews.text", "reviews.title", "reviews.rating"])

# %%
df.shape
# Out:
# (67843, 27)

# %% [markdown]
# ## SENTIMENT MODEL

# %%
sentiment_model = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda:0

# %%
def process_review(review):
    result = sentiment_model(review)[0]
    label = result["label"].lower()
    return label  # returns "positive", "negative", or "neutral"

# %%
def get_sentiment(text):
    if not isinstance(text, str) or not text.strip():
        return "neutral"

    result = sentiment_model(text[:512])[0]   # truncate very long reviews
    label = result["label"].lower()          # POSITIVE  NEGATIVE  NEUTRAL
    return label

# %% [markdown]
# ## REVIEW SENTIMENT

# %%
df["full_review"] = (
    df["reviews.title"].astype(str) + " " +
    df["reviews.text"].astype(str)
).str.strip()

# %%
texts = (
    df["full_review"]
    .fillna("")
    .astype(str)
    .apply(lambda t: t[:1000])  # shorten if needed
    .tolist()
)

results = sentiment_model(texts, batch_size=16, padding=True)
df["sentiment"] = [r["label"].lower() for r in results]
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
rating_to_sentiment = {
    1: 'negative',
    2: 'negative',
    3: 'neutral',
    4: 'positive',
    5: 'positive'
}

# Apply mapping
df['reviews.sentiment'] = df['reviews.rating'].map(rating_to_sentiment)

# %%
# Save Sentiment
#output_file = "~/Downloads/Sentimient_predictions.csv"
#df.to_csv(output_file, index=False)
#print(f"Sentimient saved to {output_file}")

# Save the file inside Colab
output_file = "/content/Sentiment_predictions.csv"
df.to_csv(output_file, index=False)
print(f"Sentiment saved to {output_file}")
# Out:
# Sentiment saved to /content/Sentiment_predictions.csv

# %%
df['reviews.sentiment']
# Out:
# 0         Neutral
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 67987    Positive
# 67988    Positive
# 67989    Positive
# 67990    Positive
# 67991    Positive
# Name: reviews.sentiment, Length: 67896, dtype: object

# %%
 df['sentiment']
# Out:
# 0        negative
# 1        positive
# 2        positive
# 3        positive
# 4        positive
#            ...
# 67987    positive
# 67988    positive
# 67989    positive
# 67990    positive
# 67991    positive
# Name: sentiment, Length: 67896, dtype: object

# %% [markdown]
# ## EVALUATING THE RESULTS

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Convert to string and handle missing values
y_true = df['reviews.sentiment'].astype(str)
y_pred = df['sentiment'].astype(str)

acc_score = accuracy_score(y_true, y_pred)
print(f"Accuracy Score: {acc_score:.4f}")
# Out:
# Accuracy Score: 0.9214

# %%
from google.colab import files
files.download(output_file)
